# %%
import math

n = math.sqrt(9.0)

print(n)

# %%
# !ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Sep  9 13:22 .
# drwxr-xr-x 1 root root 4096 Sep 15 02:09 ..
# drwxr-xr-x 4 root root 4096 Sep  9 13:21 .config
# drwxr-xr-x 1 root root 4096 Sep  9 13:22 sample_data

# %%
# !pwd
# Out:
# /content

# %%
# !ls -al /
# Out:
# total 116
# drwxr-xr-x   1 root root  4096 Sep 15 02:09 .
# drwxr-xr-x   1 root root  4096 Sep 15 02:09 ..
# drwxr-xr-x   1 root root  4096 Aug 31 13:38 bin
# drwxr-xr-x   2 root root  4096 Apr 24  2018 boot
# drwxr-xr-x   1 root root  4096 Sep  9 13:22 content
# drwxr-xr-x   1 root root  4096 Sep 13 13:20 datalab
# drwxr-xr-x   5 root root   360 Sep 15 02:09 dev
# -rwxr-xr-x   1 root root     0 Sep 15 02:09 .dockerenv
# drwxr-xr-x   1 root root  4096 Sep 15 02:09 etc
# drwxr-xr-x   2 root root  4096 Apr 24  2018 home
# drwxr-xr-x   1 root root  4096 Aug 31 13:39 lib
# drwxr-xr-x   2 root root  4096 Aug 31 13:26 lib32
# drwxr-xr-x   1 root root  4096 May 27 23:53 lib64
# drwxr-xr-x   2 root root  4096 Apr 28 00:03 media
# drwxr-xr-x   2 root root  4096 Apr 28 00:03 mnt
# -rw-r--r--   1 root root 16047 May 23 20:35 NGC-DL-CONTAINER-LICENSE
# drwxr-xr-x   1 root root  4096 Aug 31 13:41 opt
# dr-xr-xr-x 173 root root     0 Sep 15 02:09 proc
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !uname -a
# Out:
# Linux 586878108d7b 5.10.133+ #1 SMP Fri Aug 26 08:44:51 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux

# %%
# !id
# Out:
# uid=0(root) gid=0(root) groups=0(root)

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed
# bogomips	: 4399.99
# ...

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
# !nvidia-smi
# Out:
# Thu Sep 15 02:32:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pwd
# %cd ..
#cd는 쉘 밑에서 명령이기 때문에 %를 사용, linux에는 존재하지 않음#
# !pwd
# %cd content
# Out:
# /content
# /
# /
# /content

# %%
# !pwd
# !mkdir gdrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# mkdir: cannot create directory ‘gdrive’: File exists
# Mounted at /content/gdrive

# %%
# !ls -al /content/gdrive/MyDrive
# Out:
# total 653
# -rw------- 1 root root 663858 May 24  2021  20210524_194233.jpg
# drwx------ 2 root root   4096 Sep 15 02:09 'Colab Notebooks'
# -rw------- 1 root root    143 Sep 21  2021 '플래너 앱 편의성 조사.gform'

# %%
# !wget https://raw.githubusercontent.com/keras-team/keras/tf-keras/examples/mnist_cnn.py -P 'gdrive/MyDrive/Colab Notebooks'
# Out:
# --2022-09-15 02:48:26--  https://raw.githubusercontent.com/keras-team/keras/tf-keras/examples/mnist_cnn.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2270 (2.2K) [text/plain]
# Saving to: ‘gdrive/MyDrive/Colab Notebooks/mnist_cnn.py’
#
# mnist_cnn.py        100%[===================>]   2.22K  --.-KB/s    in 0.001s
#
# 2022-09-15 02:48:26 (3.01 MB/s) - ‘gdrive/MyDrive/Colab Notebooks/mnist_cnn.py’ saved [2270/2270]

# %%
# !ls -al
# !mkdir test1
# !ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Sep  9 13:22 .
# drwxr-xr-x 1 root root 4096 Sep 15 02:30 ..
# drwxr-xr-x 4 root root 4096 Sep  9 13:21 .config
# drwxr-xr-x 1 root root 4096 Sep  9 13:22 sample_data
# total 20
# drwxr-xr-x 1 root root 4096 Sep 15 02:34 .
# drwxr-xr-x 1 root root 4096 Sep 15 02:30 ..
# drwxr-xr-x 4 root root 4096 Sep  9 13:21 .config
# drwxr-xr-x 1 root root 4096 Sep  9 13:22 sample_data
# drwxr-xr-x 2 root root 4096 Sep 15 02:34 test1

# %%
import sys
print(sys.version)

import tensorflow as tf
tf.__version__
tf.test.gpu_device_name()

from tensorflow.python.client import device_lib
device_lib.list_local_devices()

print?
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]

# %%
dict1 = {"key1":1, "key2":2}
dict2 = {"key2":2, "key1":1}
print(dict1 == dict2)
# Out:
# True

# %%
student = {
    "name": "Emma",
    "class" : 9,
    "marks" : 75
}
print(student)
# Out:
# {'name': 'Emma', 'class': 9, 'marks': 75}

# %%
sampelDict = {}
type(sampelDict)
# Out:
# dict

# %%
f = dict
type(f)

# %%
d = dict()
d['adc'] = 1
d['def'] = 2
print(d)
# Out:
# {'adc': 1, 'def': 2}

# %%
newdict = dict(alice = 5, bpd = 20, tony = 15, suzy = 30)
newdict
# Out:
# {'alice': 5, 'bpd': 20, 'tony': 15, 'suzy': 30}

# %%
d['abc'] = 5
d
# Out:
# {'adc': 1, 'def': 2, 'abc': 5}

# %%
import copy
a = {'alice': [1,2,3], 'bpd' :20, 'tony' : 15, 'suzy' : 30}
b = copy.deepcopy(a)
b['alice'].append(5)
b
# Out:
# {'alice': [1, 2, 3, 5], 'bpd': 20, 'tony': 15, 'suzy': 30}

# %%
a
# Out:
# {'alice': [1, 2, 3], 'bpd': 20, 'tony': 15, 'suzy': 30}

# %%
a = {'alice': [1,2,3], 'bpd' :20, 'tony' : 15, 'suzy' : 30}
b = dict(a)
b['alice'].append(5)
b
# Out:
# {'alice': [1, 2, 3, 5], 'bpd': 20, 'tony': 15, 'suzy': 30}

# %%
a # deepcopy가 아니면 copy 당한 dict도 바뀌게 됨
# Out:
# {'alice': [1, 2, 3, 5], 'bpd': 20, 'tony': 15, 'suzy': 30}

# %%
a = {'alice': [1,2,3], 'bpd' :20, 'tony' : 15, 'suzy' : 30}
for key in a.keys():
  print(key)
# Out:
# alice
# bpd
# tony
# suzy

# %%
'bpd' in a
# Out:
# True

# %%
a['bpd']
# Out:
# 20

# %%
for val in a.values():
  print(val)
# Out:
# [1, 2, 3]
# 20
# 15
# 30

# %%
for key, val in a.items():
  print(val)
# Out:
# [1, 2, 3]
# 20
# 15
# 30
